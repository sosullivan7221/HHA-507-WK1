# %% [markdown]
# <a href="https://colab.research.google.com/github/sosullivan7221/datasci_1_loading/blob/main/HHA_507_WK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Dataset 1
#
# Description: All of the winning numbers for the Mega Millions Lottery since 2002
#
# Columns: ['Draw Date', 'Winning Numbers', 'Mega Ball', 'Multiplier']

# %%
df1 = pd.read_csv('/content/data/Lottery_Mega_Millions_Winning_Numbers__Beginning_2002.csv')

df1_f10 = df1.head(10)

df1_f10
# Out:
#     Draw Date Winning Numbers  Mega Ball  Multiplier
# 0  09/25/2020  20 36 37 48 67         16         2.0
# 1  09/29/2020  14 39 43 44 67         19         3.0
# 2  10/02/2020  09 38 47 49 68         25         2.0
# 3  10/06/2020  15 16 18 39 59         17         3.0
# 4  10/09/2020  05 11 25 27 64         13         2.0
# 5  10/13/2020  11 44 45 46 70         25         2.0
# 6  10/16/2020  27 32 50 52 57         12         5.0
# 7  10/20/2020  46 54 57 58 66         10         3.0
# 8  10/23/2020  18 34 44 60 69         22         2.0
# 9  10/27/2020  06 13 34 46 62          1         3.0

# %% [markdown]
# ## Dataset 2
#
# Description: Crime data from Los Angeles dating back to 2020
#
# Columns: ['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON']

# %%
df2 = pd.read_csv('/content/data/Crime_Data_from_2020_to_Present.csv')

df2_f10 = df2.head(10)

df2_f10
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 5  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
# 6  200100502  01/02/2020 12:00:00 AM  01/02/2020 12:00:00 AM      1315     1
# 7  200100504  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM        40     1
# 8  200100507  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM       200     1
# 9  201710201  06/19/2020 12:00:00 AM  05/26/2020 12:00:00 AM      1925    17
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# ...

# %% [markdown]
# ## Dataset 3
#
# Description: All electric and hybrid vehicles currently registered in the state of Washington.
#
# Columns: ['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract']

# %%
df3 = pd.read_csv('/content/data/Electric_Vehicle_Population_Data.csv')

df3_f10 = df3.head(10)

df3_f10
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year       Make  \
# 0  5UXTA6C03P      King    Seattle    WA      98177.0        2023        BMW
# 1  1FMCU0EZXN    Yakima      Moxee    WA      98936.0        2022       FORD
# 2  1G1FW6S03J      King    Seattle    WA      98117.0        2018  CHEVROLET
# 3  5YJSA1AC0D      King  Newcastle    WA      98059.0        2013      TESLA
# 4  1FADP5CU8F    Kitsap  Bremerton    WA      98312.0        2015       FORD
# 5  WB523CF03P    Yakima      Selah    WA      98942.0        2023        BMW
# 6  YV4BR0CK2K      King   Bellevue    WA      98004.0        2019      VOLVO
# 7  5YJ3E1EA5K  Thurston    Olympia    WA      98506.0        2019      TESLA
# 8  5YJ3E1EB6K    Yakima     Yakima    WA      98902.0        2019      TESLA
# 9  1N4AZ0CP9G      King    Redmond    WA      98052.0        2016     NISSAN
#
#      Model                   Electric Vehicle Type  \
# 0       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %% [markdown]
# ## Dataset 4
#
# Description: Monthly and Annual Averages of daily total solar resources used based on SUNY Albany's satellite radiation model.
#
# Columns:

# %%
df4 = pd.read_excel('/content/data/solarsummaries.xlsx')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-7-e13212a707d9> in <cell line: 1>()
# ----> 1 df4 = pd.read_excel('/content/data/solarsummaries.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
